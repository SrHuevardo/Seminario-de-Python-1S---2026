# %%
import sys
sys.path.append('../src')

import shipping_calculator as sc

# %%
peso_ingresado = float(input("Ingrese el peso del paquete (kg): "))
zona_ingresada = input("Ingrese la zona de destino (local/regional/nacional): ")

resultado = sc.calculate_shipping(peso_ingresado, zona_ingresada)

print(f"Ingrese el peso del paquete (kg): {peso_ingresado}")
print(f"Ingrese la zona de destino (local/regional/nacional): {zona_ingresada}")

if type(resultado) == str:
    print(resultado)
else:
    print(f"Costo de envío: ${resultado}")
# Out:
# Ingrese el peso del paquete (kg): 6.7
# Ingrese la zona de destino (local/regional/nacional): LOcal
# Costo de envío: $2000
