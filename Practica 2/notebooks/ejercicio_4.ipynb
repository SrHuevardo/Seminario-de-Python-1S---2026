# %%
import sys
sys.path.append('../src')

import email_validator as ev

# %%
correo_ingresado = input("Ingrese un email: ")

es_valido = ev.email_validator(correo_ingresado)

resultado_txt = "El email es válido." if es_valido else "El email no es válido."

print(f"Ingrese un email: {correo_ingresado}")
print(resultado_txt)
# Out:
# Ingrese un email: jasdasjdj@gmail.com
# El email es válido.
