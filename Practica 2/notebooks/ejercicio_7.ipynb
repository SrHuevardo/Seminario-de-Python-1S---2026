# %%
import sys
sys.path.append('../src')

import secret_friend as sf

# Definimos los participantes
grupo_amigos = [
    "Martín", "Sofía", "Claudio", "Ana", 
    "Lucas", "Valeria", "Diego", "Marta"
]

# %%
resultados_sorteo = sf.draw_secret_friend(grupo_amigos)

print(" RESULTADOS DEL AMIGO INVISIBLE ")
print("-" * 35)

for donante, receptor in resultados_sorteo:
    print(f" {donante} le regala a {receptor}")
# Out:
#  RESULTADOS DEL AMIGO INVISIBLE
# -----------------------------------
#  Claudio le regala a Valeria
#  Valeria le regala a Martín
#  Martín le regala a Marta
#  Marta le regala a Lucas
#  Lucas le regala a Diego
#  Diego le regala a Ana
#  Ana le regala a Sofía
#  Sofía le regala a Claudio
